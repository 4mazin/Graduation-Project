# %%
import pandas as pd

# %%
courses = pd.read_csv("clean_courses.csv")
courses
# Out:
#       Unnamed: 0                                        course_name  \
# 0              0            CS50's Introduction to Computer Science
# 1              1  Harvard CS50 – Full Computer Science Universit...
# 2              2  Introduction to Computer Science and Programmi...
# 3              3  Introduction to Electrical Engineering and Com...
# 4              4  CS50's Computer Science for Business Professio...
# ...          ...                                                ...
# 5674        5674                           Front-End Interview Prep
# 5675        5675                          Full-Stack Interview Prep
# 5676        5676              Data Structures & Algorithms in Swift
# 5677        5677                                 iOS Interview Prep
# 5678        5678                                  VR Interview Prep
#
#                                             description  \
# 0     An introduction to the intellectual enterprise...
# 1     Learn the basics of computer science from Harv...
# 2     An introduction to computer science as a tool ...
# 3     This course provides an integrated introductio...
# 4     This is CS50’s introduction to computer scienc...
# ...                                                 ...
# 5674  Answer front-end technical and behavioral inte...
# 5675  Answer common full stack and web security inte...
# 5676  Review and practice the skills technical inter...
# 5677  Answer iOS and mobile development interview qu...
# 5678  Learn how to tackle interview questions for te...
#
#                                                     url  \
# 0     https://www.classcentral.com/course/computer-s...
# 1     https://www.classcentral.com/classroom/freecod...
# 2     https://www.classcentral.com/course/computer-s...
# 3     https://www.classcentral.com/classroom/mit-ocw...
# 4     https://www.classcentral.com/course/computer-s...
# ...                                                 ...
# 5674  https://www.udacity.com//course/front-end-inte...
# 5675  https://www.udacity.com//course/full-stack-int...
# 5676  https://www.udacity.com//course/data-structure...
# 5677  https://www.udacity.com//course/ios-interview-...
# 5678  https://www.udacity.com//course/vr-interview-p...
#
#                                              clean_text
# 0     introduction intellectual enterprise computer ...
# 1     learn basic computer science harvard universit...
# 2     introduction computer science tool solve real ...
# 3     course provide integrated introduction electri...
# 4     introduction computer science business profess...
# ...                                                 ...
# 5674  answer end technical behavioral interview ques...
# 5675  answer common stack web security interview que...
# 5676  review practice skill technical interviewer ex...
# 5677  answer ios mobile development interview questi...
# 5678  learn tackle interview question technical role...
#
# [5679 rows x 5 columns]

# %%
courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5679 entries, 0 to 5678
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   5679 non-null   int64
#  1   course_name  5679 non-null   object
#  2   description  5679 non-null   object
#  3   url          5679 non-null   object
#  4   clean_text   5679 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 222.0+ KB

# %%
courses = courses.dropna(subset=['clean_text'])
courses = courses.reset_index(drop=True)
courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5679 entries, 0 to 5678
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   5679 non-null   int64
#  1   course_name  5679 non-null   object
#  2   description  5679 non-null   object
#  3   url          5679 non-null   object
#  4   clean_text   5679 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 222.0+ KB

# %%
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import normalize
import numpy as np

vectorizer = TfidfVectorizer(max_features = 5000, ngram_range=(1, 2))
tfidf_matrix = vectorizer.fit_transform(courses['clean_text'])
cosine_sim = cosine_similarity(tfidf_matrix)


# Convert each course description into a vector
courses['spacy_vector'] = courses['clean_text'].apply(lambda x: nlp(str(x)).vector)

tfidf_matrix_norm = normalize(tfidf_matrix)  

# Compute similarity separately
tfidf_sim = cosine_similarity(tfidf_matrix_norm, tfidf_matrix_norm)

# %%
def recommend_by_text(query, top_n=5):
    # TF-IDF part
    query_tfidf = vectorizer.transform([query])
    tfidf_sim = cosine_similarity(query_tfidf, tfidf_matrix_norm)

    hybrid_scores = tfidf_sim

    # Get top matches
    top_idx = hybrid_scores.argsort()[0][-top_n:][::-1]
    return courses.iloc[top_idx][['course_name', 'description', 'url']]

# %%
recommend_by_text("i want to learn about app developement", top_n=5)
# Out:
#                                            course_name  \
# 3123           Intro to iOS App Development with Swift
# 2135  Building No-Code Apps with AppSheet: Foundations
# 3140                           Firebase Analytics: iOS
# 3138                     iOS Persistence and Core Data
# 5661                            How to Make an iOS App
#
#                                             description  \
# 3123                         Make Your First iPhone App
# 2135  In this course you will learn the fundamentals...
# 3140            Improve your apps with better user data
# 3138       Learn how to store data between app launches
# 5661  Learn the process of building an app, taking y...
#
#                                                     url
# 3123  https://www.udacity.com/course/intro-to-ios-ap...
# 2135  https://www.coursera.org/learn/building-no-cod...
# 3140  https://www.udacity.com/course/firebase-analyt...
# 3138  https://www.udacity.com/course/ios-persistence...
# 5661  https://www.udacity.com//course/how-to-make-an...

# %%
from sentence_transformers import SentenceTransformer, util
import numpy as np

# Initialize model
sbert_model = SentenceTransformer('all-MiniLM-L6-v2')

# Encode texts
embeddings = sbert_model.encode(
    courses['clean_text'].tolist(),
    convert_to_numpy=True
)

sbert_embeddings_norm = normalize(embeddings)

# %%
def recommend(course_name, top_n=5):
    idx = courses[courses['course_name'] == course_name].index[0]
    scores = util.cos_sim(embeddings[idx], embeddings)[0]
    top_indices = np.argsort(-scores)[1:top_n+1]
    return courses.iloc[top_indices][['course_name', 'description', 'url']]

# %%
recommend("Data Analyst", top_n=5)
# Out:
#                                             course_name  \
# 3255                       How to Become a Data Analyst
# 5551                             Intro to Data Analysis
# 3526         Introduction to Data Analytics with Python
# 3962  Microsoft Future Ready: Introduction to Python...
# 3101                             Intro to Data Analysis
#
#                                             description  \
# 3255  Use Python, SQL, and statistics to uncover ins...
# 5551  Explore a variety of datasets, posing and answ...
# 3526  Learn the fundamentals of using Python for dat...
# 3962  _x000D_\nUncover how to use Python programming...
# 3101                 Data Analysis Using NumPy & Pandas
#
#                                                     url
# 3255  https://www.udacity.com/course/data-analyst-na...
# 5551  https://www.udacity.com//course/intro-to-data-...
# 3526  https://www.futurelearn.com/courses/introducti...
# 3962  https://www.futurelearn.com/courses/introducti...
# 3101  https://www.udacity.com/course/intro-to-data-a...

# %%
zeros_rows = courses[courses['spacy_vector'].apply(lambda v: np.all(np.array(v) == 0.0))]['course_name'].count()
print(zeros_rows)
# Out:
# 9

# %%
courses.head()
# Out:
#    Unnamed: 0                                        course_name  \
# 0           0            CS50's Introduction to Computer Science
# 1           1  Harvard CS50 – Full Computer Science Universit...
# 2           2  Introduction to Computer Science and Programmi...
# 3           3  Introduction to Electrical Engineering and Com...
# 4           4  CS50's Computer Science for Business Professio...
#
#                                          description  \
# 0  An introduction to the intellectual enterprise...
# 1  Learn the basics of computer science from Harv...
# 2  An introduction to computer science as a tool ...
# 3  This course provides an integrated introductio...
# 4  This is CS50’s introduction to computer scienc...
#
#                                                  url  \
# 0  https://www.classcentral.com/course/computer-s...
# 1  https://www.classcentral.com/classroom/freecod...
# 2  https://www.classcentral.com/course/computer-s...
# 3  https://www.classcentral.com/classroom/mit-ocw...
# 4  https://www.classcentral.com/course/computer-s...
#
#                                           clean_text  \
# 0  introduction intellectual enterprise computer ...
# 1  learn basic computer science harvard universit...
# 2  introduction computer science tool solve real ...
# 3  course provide integrated introduction electri...
# 4  introduction computer science business profess...
#
#                                         spacy_vector
# 0  [-0.74563706, 0.21714112, 0.07900714, -0.10601...
# 1  [-0.73138386, 0.26928508, 0.04624372, -0.18004...
# 2  [-0.6807582, 0.3142632, -0.09913699, -0.107650...
# 3  [-0.72200805, 0.23780149, -0.062220402, -0.111...
# 4  [-0.6797, 0.22705002, 0.012623596, 0.0211236, ...

# %%
# Save models
with open("tfidf_vectorizer.pkl", "wb") as f:
    pickle.dump(vectorizer, f)
with open("tfidf_matrix.pkl", "wb") as f:
    pickle.dump(tfidf_matrix, f)

courses.to_pickle("courses_with_vectors.pkl")
np.save("sbert_embeddings.npy", sbert_embeddings_norm)
